# %%
# !python contact_process.py -l 1.5 -N 100 -tTrans 0 -tTotal 100 -graph ring -X0 1 -fX0 0.0 -sim aval -outputFile debug/cp_ring_l1.5_par_aval_N100_fX00.0.mat -saveSites -writeOnRun -update parallel -mergespkfile -iterdynamics tome_oliveira
# !python contact_process.py -l 1.5 -N 100 -tTrans 0 -tTotal 100 -graph ring -X0 1 -fX0 0.0 -sim aval -outputFile debug/cp_ring_l1.5_par_aval_N100_fX00.0.mat -saveSites -writeOnRun -update parallel -mergespkfile -iterdynamics tome_oliveira
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 100
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#             dtsample: 1
#           expandtime: False
#                  fX0: 0.0
#                graph: <GraphType.RING: 1>
#         iterdynamics: <StateIterType.TOME_OLIVEIRA: 0>
#                    l: 1.5
#         mergespkfile: True
#             noX0Rand: False
#           outputFile: 'debug/cp_ring_l1.5_par_aval_N100_fX00.0.mat'
#            saveSites: True
#                  sim: <SimulationType.AVAL: 1>
#          spkFileName: 'debug/cp_ring_l1.5_par_aval_N100_fX00.0_spk.txt'
#               tTotal: 100
#               tTrans: 0
#               update: <UpdateType.PARALLEL: 0>
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 100
# ...

# %%
# !python contact_process.py -l 1.5 -N 100 -tTrans 0 -tTotal 100 -graph ring -X0 1 -fX0 0.0 -sim aval -outputFile debug/cp_ring_l1.5_seq_aval_N100_fX00.0.mat -saveSites -writeOnRun -update sequential -mergespkfile -iterdynamics tome_oliveira -expandtime -dtsample 100
# !python contact_process.py -l 1.5 -N 100 -tTrans 0 -tTotal 100 -graph ring -X0 1 -fX0 0.0 -sim aval -outputFile debug/cp_ring_l1.5_seq_aval_N100_fX00.0.mat -saveSites -writeOnRun -update sequential -mergespkfile -iterdynamics tome_oliveira -expandtime -dtsample 1
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 100
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 0.01
#             dtsample: 100
#           expandtime: True
#                  fX0: 0.0
#                graph: <GraphType.RING: 1>
#         iterdynamics: <StateIterType.TOME_OLIVEIRA: 0>
#                    l: 1.5
#         mergespkfile: True
#             noX0Rand: False
#           outputFile: 'debug/cp_ring_l1.5_seq_aval_N100_fX00.0_2.mat'
#            saveSites: True
#                  sim: <SimulationType.AVAL: 1>
#          spkFileName: 'debug/cp_ring_l1.5_seq_aval_N100_fX00.0_2_spk.txt...
#               tTotal: 100
#               tTrans: 0
#               update: <UpdateType.SEQUENTIAL: 1>
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 10000
# ...

# %%
import modules.io as io
import matplotlib.pyplot as plt

d_samp1 = io.import_mat_file('debug/cp_ring_l1.5_seq_aval_N100_fX00.0_1_merged.mat')
d_sampN = io.import_mat_file('debug/cp_ring_l1.5_seq_aval_N100_fX00.0_merged.mat')

print('rho size = ',d_samp1.rho.size)
print('rho size = ',d_sampN.rho.size)

plt.plot(d_samp1.time,d_samp1.rho,'-o',label='dtsamp=1')
plt.plot(d_sampN.time,d_sampN.rho,'-s',label='dtsamp=N')
plt.show()
# Out:
# rho size =  10000
# rho size =  102

# %%
print(d_samp1.X_time)
print(d_sampN.X_time)
# Out:
# [6.000e-02 3.600e-01 7.400e-01 1.590e+00 1.750e+00 4.080e+00 4.350e+00
#  4.380e+00 5.360e+00 5.960e+00 6.330e+00 6.900e+00 7.140e+00 7.660e+00
#  8.010e+00 8.210e+00 8.310e+00 1.068e+01 1.133e+01 1.191e+01 1.270e+01
#  1.418e+01 1.752e+01 1.769e+01 1.817e+01 2.048e+01 2.098e+01 2.154e+01
#  2.216e+01 2.226e+01 2.346e+01 2.406e+01 2.593e+01 2.699e+01 2.722e+01
#  2.742e+01 2.746e+01 2.850e+01 2.877e+01 2.896e+01 2.899e+01 2.952e+01
#  2.972e+01 2.982e+01 2.995e+01 3.041e+01 3.054e+01 3.065e+01 3.135e+01
#  3.202e+01 3.256e+01 3.377e+01 3.380e+01 3.382e+01 3.439e+01 3.549e+01
#  3.607e+01 3.676e+01 3.678e+01 3.772e+01 3.780e+01 3.839e+01 3.896e+01
#  3.913e+01 3.928e+01 3.998e+01 4.176e+01 4.190e+01 4.269e+01 4.318e+01
#  4.341e+01 4.530e+01 4.533e+01 4.541e+01 4.579e+01 4.585e+01 4.646e+01
#  4.696e+01 4.894e+01 4.965e+01 5.095e+01 5.103e+01 5.128e+01 5.164e+01
#  5.202e+01 5.206e+01 5.232e+01 5.250e+01 5.286e+01 5.300e+01 5.303e+01
# ...

# %%
# !python contact_process.py -l 1.5 -N 2560 -tTrans 0 -tTotal 1100 -graph ring -X0 1 -fX0 0.0 -sim aval -outputFile debug/cp_ring_l1.5_seq_aval_N2560_fX00.0.mat -saveSites -writeOnRun -update sequential -mergespkfile -iterdynamics tome_oliveira
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 2560
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#             dtsample: 1
#           expandtime: False
#                  fX0: 0.0
#                graph: <GraphType.RING: 1>
#         iterdynamics: <StateIterType.TOME_OLIVEIRA: 0>
#                    l: 1.5
#         mergespkfile: True
#             noX0Rand: False
#           outputFile: 'debug/cp_ring_l1.5_seq_aval_N2560_fX00.0_1.mat'
#            saveSites: True
#                  sim: <SimulationType.AVAL: 1>
#          spkFileName: 'debug/cp_ring_l1.5_seq_aval_N2560_fX00.0_1_spk.tx...
#               tTotal: 1100
#               tTrans: 0
#               update: <UpdateType.SEQUENTIAL: 1>
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 1100
# ...

# %%
import modules.io as io
import matplotlib.pyplot as plt

d = io.import_mat_file('debug/cp_ring_l1.5_seq_aval_N2560_fX00.0_merged.mat')
print(d)

plt.plot(d.time,d.rho,'-')
# Out:
# structtype(
#                    M: 100
#                    N: 2560
#                   X0: 1
#               X0Rand: 1
#                X_ind: array([1278, 1279, 1277, ..., 1279, 1279, 1280])
#               X_time: array([   2.,    2.,    3., ..., 1095., 1096., 109...
#             X_values: array([1., 1., 1., ..., 1., 1., 1.])
#             cmd_line: 'contact_process.py -l 1.5 -N 2560 -tTrans 0 -tTot...
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: 0
#                  fX0: 0.0
#                graph: 'ring'
#         iterdynamics: 'tome_oliveira'
#                    l: 1.5
#         mergespkfile: 1
#             noX0Rand: 0
#           outputFile: 'debug/cp_ring_l1.5_seq_aval_N2560_fX00.0.mat'
#                  rho: array([0.        , 0.00039063, 0.00078125, ..., 0....
#            saveSites: 1
#                  sim: 'aval'
#          spkFileName: array([], dtype='<U1')
# ...

# %%
# !python contact_process.py -l 1.5 -N 2560 -tTrans 0 -tTotal 1100 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l1.5_par_aval_N2560_fX00.mat -saveSites -writeOnRun -update parallel -mergespkfile -iterdynamics marro_dickman
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 2560
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: <GraphType.ALLTOALL: 0>
#         iterdynamics: <StateIterType.MARRO_DICKMAN: 1>
#                    l: 0.7
#         mergespkfile: True
#             noX0Rand: False
#           outputFile: 'debug/cp_mf_l0.7_par_aval_N2560_t80000_fX00.mat'
#            saveSites: True
#                  sim: <SimulationType.AVAL: 1>
#          spkFileName: 'debug/cp_mf_l0.7_par_aval_N2560_t80000_fX00_spk.t...
#               tTotal: 1100
#               tTrans: 0
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 1100
# ...

# %%
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 1100 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel -mergespkfile
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: <GraphType.RING: 1>
#                    l: 3.0
#         mergespkfile: True
#             noX0Rand: False
#           outputFile: 'debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00_6....
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00_6_...
#               tTotal: 1100
#               tTrans: 1000
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 1100
# *** writing file  debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00_6_spk.txt  during simulation
# * End of simulation... Total time: 0:00:09.500000
# ...

# %%
# !mkdir debug
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l3.297848_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l4.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l3.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l3.297848_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile debug/cp_ring_l4.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential

# all to all graph (mean-field sim)
# !python -O contact_process.py -l 0.8 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l0.8_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.0 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l1.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.2 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l1.2_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 0.8 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l0.8_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 1.0 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l1.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 1.2 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile debug/cp_mf_l1.2_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'ring'
#                    l: 3.0
#         mergespkfile: False
#             noX0Rand: False
#           outputFile: 'debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00.ma...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'debug/cp_ring_l3.0_par_aval_N10000_t50000_fX00_sp...
#               tTotal: 50000
#               tTrans: 1000
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 50000
# c:\Program Files\Python38\lib\site-packages\pycparser\c_parser.py:20: RuntimeWarning: parsing methods must have __doc__ for pycparser to work properly
# ...

# %%
# !mkdir test_sim_corr_ring
# !mkdir test_sim_corr_ringf
# !mkdir test_sim_corr_mf

# %% [markdown]
# # periodic ring

# %%
# periodic ring 
# !python -O contact_process.py -l 1.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l1.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 2.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l2.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l3.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l3.297848_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l4.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 5.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l5.0_par_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l1.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 2.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l2.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l3.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l3.297848_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l4.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 5.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ring -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ring/cp_ring_l5.0_seq_aval_N10000_t50000_fX00.mat      -saveSites -writeOnRun -update sequential
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'ring'
#                    l: 1.0
#             noX0Rand: False
#           outputFile: 'test_sim_corr_ring/cp_ring_l1.0_par_aval_N10000_t...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'test_sim_corr_ring/cp_ring_l1.0_par_aval_N10000_t...
#               tTotal: 50000
#               tTrans: 1000
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 50000
# spk file opened: test_sim_corr_ring/cp_ring_l1.0_par_aval_N10000_t50000_fX00_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:17.757026
# ...

# %% [markdown]
# # free BC ring

# %%
# free boundary ring
# !python -O contact_process.py -l 1.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l1.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 2.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l2.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l3.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l3.297848_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l4.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 5.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l5.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l1.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 2.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l2.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 3.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l3.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 3.297848 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l3.297848_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 4.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l4.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 5.000000 -N 1000 -tTrans 1000 -tTotal 50000 -graph ringfree -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_ringf/cp_ringfree_l5.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'ringfree'
#                    l: 1.0
#             noX0Rand: False
#           outputFile: 'test_sim_corr_ringf/cp_ringfree_l1.0_par_aval_N10...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'test_sim_corr_ringf/cp_ringfree_l1.0_par_aval_N10...
#               tTotal: 50000
#               tTrans: 1000
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 50000
# spk file opened: test_sim_corr_ringf/cp_ringfree_l1.0_par_aval_N10000_t50000_fX00_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:15.674832
# ...

# %% [markdown]
# # mean-field

# %%
# all to all graph (mean-field sim)
# !python -O contact_process.py -l 0.7 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.7_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 0.8 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.8_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 0.9 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.9_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.0 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.0_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.1 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.1_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 1.2 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.2_par_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update parallel
# !python -O contact_process.py -l 0.7 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.7_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 0.8 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.8_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 0.9 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l0.9_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 1.0 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.0_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 1.1 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.1_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# !python -O contact_process.py -l 1.2 -N 1000 -tTrans 1000 -tTotal 50000 -graph alltoall -X0 1 -fX0 0 -sim aval -outputFile test_sim_corr_mf/cp_mf_l1.2_seq_aval_N10000_t50000_fX00.mat -saveSites -writeOnRun -update sequential
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'alltoall'
#                    l: 0.7
#             noX0Rand: False
#           outputFile: 'test_sim_corr_mf/cp_mf_l0.7_par_aval_N10000_t5000...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'test_sim_corr_mf/cp_mf_l0.7_par_aval_N10000_t5000...
#               tTotal: 50000
#               tTrans: 1000
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 50000
# spk file opened: test_sim_corr_mf/cp_mf_l0.7_par_aval_N10000_t50000_fX00_spk.txt
# spk file close
# * End of simulation... Total time: 0:00:31.182273
# ...

# %%
raise SystemExit("Execution stopped at this cell.")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Execution stopped at this cell.
# /home/mgirardi/pylocal/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !python contact_process.py -h
# Out:
# usage: contact_process.py [-h] [-l l_PARAM] [-N N_PARAM] [-M M_PARAM]
#                           [-X0 X0_PARAM] [-fX0 fX0_PARAM]
#                           [-tTotal tTotal_PARAM] [-tTrans tTrans_PARAM]
#                           [-graph GRAPH_TYPE] [-update UPDATE_TYPE]
#                           [-sim SIM_TYPE] [-noX0Rand] [-saveSites]
#                           [-writeOnRun] [-expandtime]
#                           [-outputFile OUTPUT_FILE_NAME]
#
# Contact process in 1+1 dimensions or mean-field all-to-all graph
#
# (l_c=3.297848 for ring; l_c=1 for mean-field)
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -l l_PARAM            CP rate (l_c=3.297848 for ring; l_c=1 for mean-field)
#   -N N_PARAM            number of sites in the network
#   -M M_PARAM            number of memory time steps for quasistationary simulation (whenever the system goes into absorbing, it is placed in a random state chosen from the last M visited states)
# ...

# %%
# !python -O contact_process.py -l 2.0 -N 1000 -tTrans 0 -tTotal 10000 -graph ring -X0 1 -fX0 0 -outputFile test_sim_corr/cp_ring_l2.0_aval_N1000_t10000_fX00.mat -update parallel -saveSites -writeOnRun -sim aval
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'ring'
#                    l: 2.0
#             noX0Rand: False
#           outputFile: 'test_sim_corr/cp_ring_l2.0_aval_N1000_t10000_fX00...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'test_sim_corr/cp_ring_l2.0_aval_N1000_t10000_fX00...
#               tTotal: 10000
#               tTrans: 0
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 10000
# spk file opened: test_sim_corr/cp_ring_l2.0_aval_N1000_t10000_fX00_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:04.140000
# ...

# %%
# !python -O contact_process.py -l 3.0 -N 1000 -tTrans 0 -tTotal 10000 -graph ring -X0 1 -fX0 0 -outputFile test_sim_corr/cp_ring_l3.0_aval_N1000_t10000_fX00.mat -update parallel -saveSites -writeOnRun -sim aval
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 0.0
#                graph: 'ring'
#                    l: 3.0
#             noX0Rand: False
#           outputFile: 'test_sim_corr/cp_ring_l3.0_aval_N1000_t10000_fX01...
#            saveSites: True
#                  sim: 'aval'
#          spkFileName: 'test_sim_corr/cp_ring_l3.0_aval_N1000_t10000_fX01...
#               tTotal: 10000
#               tTrans: 0
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 10000
# spk file opened: test_sim_corr/cp_ring_l3.0_aval_N1000_t10000_fX01_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:20.672000
# ...

# %%
# !python -O contact_process.py -l 3.0 -N 1000 -tTotal 10000 -graph ring -X0 1 -fX0 1 -outputFile cp_ring_l3.0_aval_N1000_t10000_fX01.mat -update parallel -saveSites -writeOnRun
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#            docstring: 'usage: contact_process.py [-h] [-l l_PARAM] [-N N...
#                   dt: 1.0
#           expandtime: False
#                  fX0: 1.0
#                graph: 'ring'
#                    l: 3.0
#             noX0Rand: False
#           outputFile: 'cp_ring_l3.0_aval_N1000_t10000_fX01.mat'
#            saveSites: True
#                  sim: 'timeevo'
#          spkFileName: 'cp_ring_l3.0_aval_N1000_t10000_fX01_spk.txt'
#               tTotal: 10000
#               tTrans: 0
#               update: 'parallel'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 10000
# spk file opened: cp_ring_l3.0_aval_N1000_t10000_fX01_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:23.375000
# * Writing ... cp_ring_l3.0_aval_N1000_t10000_fX01.mat
# ...

# %%
import modules.io as io
import matplotlib.pyplot as plt

d = io.import_mat_file('test_sim_results/cp_ring_l3.0_aval_N1000_t10000_fX01.mat')
#print(d)

fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(8,6))

ax[0].plot(d.time,d.rho,'-')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Density')
ax[0].set_xscale('log')
ax[0].set_yscale('log')

ax[1].scatter(d.X_time, d.X_ind, s=0.01)
ax[1].set_xlabel('Time')
ax[1].set_ylabel('Site #')
ax[1].set_xscale('log')

plt.tight_layout()

plt.show()

# %%
# !python -O contact_process.py -l 3.0 -N 1000 -tTotal 10000 -graph ring -X0 1 -outputFile cp_ring_l3.0_aval_N1000_t10000.mat -saveSites -writeOnRun
# Out:
# * Simulation parameters:
# structtype(
#                    M: 100
#                    N: 1000
#                   X0: 1
#               X0Rand: True
#                   dt: 0.001
#           expandtime: True
#                  fX0: 0.5
#                graph: 'ring'
#                    l: 3.0
#             noX0Rand: False
#           outputFile: 'cp_ring_l3.0_aval_N1000_t10000.mat'
#            saveSites: True
#                  sim: 'timeevo'
#          spkFileName: 'cp_ring_l3.0_aval_N1000_t10000_spk.txt'
#               tTotal: 10000
#               tTrans: 0
#               update: 'seq'
#           writeOnRun: True
# )
# * Running simulation... Total time steps = 10000000
# spk file opened: cp_ring_l3.0_aval_N1000_t10000_spk.txt
# spk file close
# * End of simulation... Total time: 0:01:39.204000
# * Writing ... cp_ring_l3.0_aval_N1000_t10000.mat
# done

# %%
import modules.io as io
import matplotlib.pyplot as plt

d = io.import_mat_file('test_sim_results/cp_ring_l3.0_aval_N1000_t10000_1.mat')
#print(d)

fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(8,6))

ax[0].plot(d.time,d.rho,'-')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Density')

ax[1].scatter(d.X_time, d.X_ind, s=0.01)
ax[1].set_xlabel('Time')
ax[1].set_ylabel('Site #')

plt.tight_layout()

plt.show()
